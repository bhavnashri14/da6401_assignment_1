# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls /content/drive/MyDrive/da6401_assignment_1
# Out:
# models	notebooks  README.md  requirements.txt	src

# %%
rm -rf .git
# Out:
# rm: cannot remove '.git/objects': Directory not empty

# %%
import wandb
wandb.login()
# Out:
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice:
#  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
# wandb: WARNING Invalid choice
# wandb: Enter your choice:
#  2
# wandb: You chose 'Use an existing W&B account'
# wandb: Logging into https://api.wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: Create a new API key at: https://wandb.ai/authorize?ref=models
# wandb: Store your API key securely and do not share it.
# wandb: Paste your API key and hit enter:
#  ··········
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# ...

# %%
# !python /content/drive/MyDrive/da6401_assignment_1/src/train.py -d mnist -e 10 -b 64 -lr 0.001 -o rmsprop
# Out:
# 2026-03-04 17:11:26.264164: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-03-04 17:11:26.270155: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-03-04 17:11:26.298146: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1772644286.323814   20475 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1772644286.331389   20475 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
import wandb
import numpy as np
import matplotlib.pyplot as plt
from utils.data_loader import load_data

# Initialize W&B
wandb.init(project="da6401_assignment1", name="mnist_data_exploration")

# Load MNIST
X_train, y_train, _, _ = load_data("mnist")

# Convert one-hot to labels
labels = np.argmax(y_train, axis=1)

# Create W&B table
table = wandb.Table(columns=["Class", "Image"])

# For each digit 0–9
for digit in range(10):
    idx = np.where(labels == digit)[0][:5]  # first 5 samples

    for i in idx:
        img = X_train[i].reshape(28, 28)
        table.add_data(
            digit,
            wandb.Image(img, caption=f"Digit: {digit}")
        )

# Log table
wandb.log({"MNIST Sample Images": table})

wandb.finish()
# Out:
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/content/wandb/run-20260225_070003-a2hyzdql</code>
# Syncing run <strong><a href='https://wandb.ai/bhavnashri-a-iit-madras-foundation/da6401_assignment1/runs/a2hyzdql' target="_blank">mnist_data_exploration</a></strong> to <a href='https://wandb.ai/bhavnashri-a-iit-madras-foundation/da6401_assignment1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/bhavnashri-a-iit-madras-foundation/da6401_assignment1' target="_blank">https://wandb.ai/bhavnashri-a-iit-madras-foundation/da6401_assignment1</a>
#  View run at <a href='https://wandb.ai/bhavnashri-a-iit-madras-foundation/da6401_assignment1/runs/a2hyzdql' target="_blank">https://wandb.ai/bhavnashri-a-iit-madras-foundation/da6401_assignment1/runs/a2hyzdql</a>
# ...

# %%
# !python /content/drive/MyDrive/da6401_assignment_1/src/train.py -o sgd -e 5 -nhl 3 -sz 128 128 128 -a relu
# !python /content/drive/MyDrive/da6401_assignment_1/src/train.py -o momentum -e 5 -nhl 3 -sz 128 128 128 -a relu
# !python /content/drive/MyDrive/da6401_assignment_1/src/train.py -o nag -e 5 -nhl 3 -sz 128 128 128 -a relu
# !python /content/drive/MyDrive/da6401_assignment_1/src/train.py -o rmsprop -e 5 -nhl 3 -sz 128 128 128 -a relu
# !python /content/drive/MyDrive/da6401_assignment_1/src/train.py -o adam -e 5 -nhl 3 -sz 128 128 128 -a relu
# !python /content/drive/MyDrive/da6401_assignment_1/src/train.py -o nadam -e 5 -nhl 3 -sz 128 128 128 -a relu
# Out:
# 2026-02-27 05:59:16.272378: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-02-27 05:59:16.277338: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-02-27 05:59:16.294772: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1772171956.323816    1844 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1772171956.332314    1844 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python /content/drive/MyDrive/da6401_assignment_1/src/train.py -o adam -l cross_entropy -e 5 -nhl 3 -sz 128 128 128 -a sigmoid
# !python /content/drive/MyDrive/da6401_assignment_1/src/train.py -o adam -l mse -e 5 -nhl 3 -sz 128 128 128 -a sigmoid
# Out:
# 2026-02-27 06:09:41.987821: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-02-27 06:09:41.992409: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-02-27 06:09:42.006450: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1772172582.029856    4603 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1772172582.037008    4603 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python /content/drive/MyDrive/da6401_assignment_1/src/train.py -o adam -l cross_entropy -e 5 -nhl 3 -sz 128 128 128 -a sigmoid
# !python /content/drive/MyDrive/da6401_assignment_1/src/train.py -o adam -l mse -e 5 -nhl 3 -sz 128 128 128 -a sigmoid
